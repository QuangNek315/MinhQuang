# %%
# Dấu # dùng để ghi chú
# Shift + Enter: run đoạn code và thêm một dòng mới

# %%
# Ctrl + Enter: run đoạn code

# %%
# !pip install pillow

# %%
# Thêm thư viện
from PIL import Image
from AnhDeptools import *

# %%
# Khai báo một biến chứa thư mục
dir = 'D:/DangDucMinhQuang/AnhDep'

# %%
# Đọc nhiều ảnh
AnhDeps = get_image_list(dir)

# %%
for AnhDep in AnhDeps:
    print(AnhDep.size)
    display(AnhDep)
# Out:
# (168, 158)
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=168x158>
# (196, 183)
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=196x183>
# (178, 168)
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=178x168>
# (204, 192)
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=204x192>
# (159, 150)
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=159x150>
# (190, 179)
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=190x179>
# (168, 158)
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=168x158>
# (168, 158)
# <PIL.PngImagePlugin.PngImageFile image mode=RGB size=168x158>
