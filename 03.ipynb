# %%
# Import thư viện
from PIL import Image
from AnhDeptools import *

# %%
# Đường dẫn ảnh
my_path = 'D:/DangDucMinhQuang/AnhDep/01.jpg'

# %%
# Đọc ảnh 
AnhDep = load_image(my_path)

# %%
display(AnhDep)
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=168x158>

# %%
# Kích thước ban đầu
print(AnhDep.size)
# Out:
# (168, 158)

# %%
# Thay đổi kích thước của ảnh 
new_size = (1000,1000)
new_image = AnhDep.resize(new_size)
display(new_image)
# Out:
# <PIL.Image.Image image mode=RGB size=1000x1000>

# %%
# Thay đổi kích 
thumbnail_size = (50,50)
AnhDep.thumbnail(thumbnail_size)
display(AnhDep)
# Task: lưu ảnh xuống
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=50x47>
