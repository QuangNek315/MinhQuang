# %%
# import thư viện
from PIL import Image
from AnhDeptools import *

# %%
# Đường dẫn ảnh
my_path = 'D:/DangDucMinhQuang/AnhDep/01.jpg'

# %%
# Đọc ảnh
AnhDep = load_image(my_path)

# %%
display(AnhDep)
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=168x158>

# %%
# chuyển từ ảnh RGB sang ảnh xám
gray_image = AnhDep.convert("L")
display(gray_image)
# Out:
# <PIL.Image.Image image mode=L size=168x158>

# %%
# Phân RGB thành 3 tầng màu khác nhau
red_band, green_band, blue_band = AnhDep.split()
display(red_band)
display(green_band)
display(blue_band)
# Out:
# <PIL.Image.Image image mode=L size=168x158>
# <PIL.Image.Image image mode=L size=168x158>
# <PIL.Image.Image image mode=L size=168x158>

# %%
merged_image = Image.merge("RGB", (red_band, green_band, blue_band))
display(merged_image)
# Out:
# <PIL.Image.Image image mode=RGB size=168x158>

# %%
merged_image = Image.merge("RGB", (green_band, blue_band, red_band))
display(merged_image)
# Out:
# <PIL.Image.Image image mode=RGB size=168x158>
